# %%
##Read the csv file
import pandas as pd
import numpy as np
df1 = pd.read_csv("E:/Rakib Bhai/MinMax.csv")
df1
# Out:
#       Marital status  Application mode  Application order  Course  \
# 0           0.285714          0.555556           0.013858       1
# 1           0.250000          0.111111           0.925989       1
# 2           0.000000          0.555556           0.907512       1
# 3           0.285714          0.222222           0.978108       1
# 4           0.678571          0.111111           0.801466       0
# ...              ...               ...                ...     ...
# 4419        0.000000          0.666667           0.978108       1
# 4420        0.000000          0.222222           0.978108       1
# 4421        0.000000          0.111111           0.950693       1
# 4422        0.000000          0.111111           0.915244       1
# 4423        0.160714          0.111111           0.978108       1
#
#       Daytime/evening attendance\t  Previous qualification  \
# 0                              0.0                0.284211
# 1                              0.0                0.684211
# 2                              0.0                0.284211
# 3                              0.0                0.284211
# 4                              0.0                0.052632
# ...                            ...                     ...
# 4419                           0.0                0.315789
# 4420                           0.0                0.263158
# 4421                           0.0                0.621053
# 4422                           0.0                0.894737
# 4423                           0.0                0.600000
#
#       Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           0.000000     0.418605                0.255814
# 1                           0.000000     0.000000                0.046512
# 2                           0.000000     0.837209                0.837209
# 3                           0.000000     0.860465                0.837209
# 4                           0.000000     0.837209                0.860465
# ...                              ...          ...                     ...
# 4419                        0.000000     0.000000                0.000000
# 4420                        0.962963     0.000000                0.000000
# 4421                        0.000000     0.837209                0.837209
# 4422                        0.000000     0.837209                0.837209
# 4423                        0.194444     0.860465                0.837209
#
#       Father's qualification  ...  Curricular units 2nd sem (credited)  \
# 0                   0.025773  ...                             0.000000
# 1                   0.015464  ...                             0.260870
# 2                   0.046392  ...                             0.260870
# 3                   0.025773  ...                             0.260870
# 4                   0.046392  ...                             0.260870
# ...                      ...  ...                                  ...
# 4419                0.025773  ...                             0.260870
# 4420                0.046392  ...                             0.260870
# 4421                0.046392  ...                             0.347826
# 4422                0.036082  ...                             0.217391
# 4423                0.025773  ...                             0.260870
#
#       Curricular units 2nd sem (enrolled)  \
# 0                                0.000000
# 1                                0.181818
# 2                                0.000000
# 3                                0.303030
# 4                                0.181818
# ...                                   ...
# 4419                             0.242424
# 4420                             0.181818
# 4421                             0.272727
# 4422                             0.181818
# 4423                             0.181818
#
#       Curricular units 2nd sem (evaluations)  \
# 0                                       0.00
# 1                                       0.30
# 2                                       0.00
# 3                                       0.25
# 4                                       0.30
# ...                                      ...
# 4419                                    0.25
# 4420                                    0.10
# 4421                                    0.05
# 4422                                    0.25
# 4423                                    0.30
#
#       Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 0                                0.000000                               0.0
# 1                                0.735897                               0.0
# 2                                0.000000                               0.0
# 3                                0.667692                               0.0
# 4                                0.700000                               0.0
# ...                                   ...                               ...
# 4419                             0.682051                               0.0
# 4420                             0.592308                               0.0
# 4421                             0.726923                               0.0
# 4422                             0.646154                               0.0
# 4423                             0.700000                               0.0
#
#       Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 0                                           0.372093           0.488889
# 1                                           0.732558           0.111111
# 2                                           0.372093           0.488889
# 3                                           0.209302           0.000000
# 4                                           0.732558           0.111111
# ...                                              ...                ...
# 4419                                        0.918605           0.800000
# 4420                                        0.406977           0.311111
# 4421                                        0.732558           0.111111
# 4422                                        0.209302           0.000000
# 4423                                        0.593023           1.000000
#
#       Inflation rate  GDP  Target
# 0           0.766182  0.0       0
# 1           0.640687  1.0       2
# 2           0.766182  0.0       0
# 3           0.124174  1.0       2
# 4           0.640687  1.0       2
# ...              ...  ...     ...
# 4419        0.000000  1.0       2
# 4420        0.803170  0.0       0
# 4421        0.640687  0.0       0
# 4422        0.124174  1.0       2
# 4423        0.311757  1.0       2
#
# [4424 rows x 37 columns]

# %% [markdown]
# # Correlation between various features with a heatmap

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(30,30))
ax = sns.heatmap(df1.corr(), annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# # Top 10 Highest Correlated Features

# %%
correlations = df1.corr()['Target'].drop('Target')
top_10_features = correlations.abs().nlargest(10).index
top_10_corr_values = correlations[top_10_features].values

plt.figure(figsize=(10, 8))
plt.bar(x=top_10_features, height=top_10_corr_values, color='skyblue')
plt.xlabel('Features')
plt.ylabel('Correlation with Student Status')
plt.title('Top 10 Features with Highest Correlation to Student Status')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # DataFrame with only the top 10 features and Target

# %%
top_10_df = df1[top_10_features.to_list() + ['Target']].copy()
top_10_corr = top_10_df.corr()[['Target']]
sorted_corr = top_10_corr.sort_values(by='Target', key=lambda x: abs(x), ascending=False)
plt.figure(figsize=(5, 10))
sns.heatmap(sorted_corr, annot=True, center=0)
plt.title('Factors Ranker')
plt.show()

# %%
top_10_df
# Out:
#       GDP  Curricular units 2nd sem (evaluations)  \
# 0     0.0                                    0.00
# 1     1.0                                    0.30
# 2     0.0                                    0.00
# 3     1.0                                    0.25
# 4     1.0                                    0.30
# ...   ...                                     ...
# 4419  1.0                                    0.25
# 4420  0.0                                    0.10
# 4421  0.0                                    0.05
# 4422  1.0                                    0.25
# 4423  1.0                                    0.30
#
#       Curricular units 2nd sem (approved)  \
# 0                                0.000000
# 1                                0.735897
# 2                                0.000000
# 3                                0.667692
# 4                                0.700000
# ...                                   ...
# 4419                             0.682051
# 4420                             0.592308
# 4421                             0.726923
# 4422                             0.646154
# 4423                             0.700000
#
#       Curricular units 1st sem (evaluations)  \
# 0                                   0.000000
# 1                                   0.230769
# 2                                   0.000000
# 3                                   0.230769
# 4                                   0.192308
# ...                                      ...
# 4419                                0.192308
# 4420                                0.230769
# 4421                                0.269231
# 4422                                0.192308
# 4423                                0.230769
#
#       Curricular units 1st sem (approved)  Debtor  Gender  Scholarship holder  \
# 0                                0.000000       1       0            0.056604
# 1                                0.741722       0       0            0.037736
# 2                                0.000000       0       0            0.037736
# 3                                0.711447       1       0            0.056604
# 4                                0.653422       1       0            0.528302
# ...                                   ...     ...     ...                 ...
# 4419                             0.720530       1       0            0.037736
# 4420                             0.635762       0       0            0.018868
# 4421                             0.790066       1       1            0.245283
# 4422                             0.731126       1       1            0.056604
# 4423                             0.618102       1       0            0.094340
#
#       Educational special needs  Tuition fees up to date  Target
# 0                             0                        1       0
# 1                             0                        1       2
# 2                             0                        1       0
# 3                             0                        0       2
# 4                             0                        0       2
# ...                         ...                      ...     ...
# 4419                          0                        1       2
# 4420                          1                        0       0
# 4421                          0                        0       0
# 4422                          0                        0       2
# 4423                          0                        0       2
#
# [4424 rows x 11 columns]

# %%
top_10_df.to_csv('E:/Rakib Bhai/Selected_Features.csv')
